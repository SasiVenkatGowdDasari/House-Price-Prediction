# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data=pd.read_csv("train.csv")
test_data=pd.read_csv("test.csv")
Prediction_data=pd.read_csv("test_predictions.csv")

# %%
test_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
train_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
train_data=pd.concat([train_data,test_data])

# %%
train_data.drop(['Id'],axis=1,inplace=True)

# %%
train_data.isnull().sum()
# Out:
# MSSubClass          0
# MSZoning            4
# LotFrontage       486
# LotArea             0
# Street              0
#                  ...
# MoSold              0
# YrSold              0
# SaleType            1
# SaleCondition       0
# SalePrice        1459
# Length: 80, dtype: int64

# %%
# no of clumns / Features
len(train_data.axes[1])
# Out:
# 80

# %%
# no of rows / Records
train_data.__len__()
# Out:
# 2919

# %%
# find the percentage of null values in a data set
(train_data.isnull().sum().sum()/(train_data.shape[0]*train_data.shape[1]))*100
# Out:
# 7.350976361767729

# %%
train_data.duplicated().sum()
# Out:
# 0

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2919 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2915 non-null   object
#  2   LotFrontage    2433 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2917 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
# ...

# %%
train_data.select_dtypes(include=("object")).isnull().sum().sum()
# Out:
# 15029

# %%
train_data.select_dtypes(include=("object"))
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1454       RM   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1455       RM   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Mod
#
# ...

# %%
obj_columns=train_data.select_dtypes(include=("object")).columns    # Print the all columns which are Object datatype (Catagorical data)

# %%
for i in obj_columns:
    train_data[i].fillna(train_data[i].mode()[0],inplace=True)
# Out:
# C:\Users\sasiv\AppData\Local\Temp\ipykernel_5444\3050989765.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_data[i].fillna(train_data[i].mode()[0],inplace=True)

# %%
train_data.select_dtypes(include=("object")).isnull().sum().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in obj_columns:
    train_data[i]=le.fit_transform(train_data[i])

# %%
train_data
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0             60         3         65.0     8450       1      0         3
# 1             20         3         80.0     9600       1      0         3
# 2             60         3         68.0    11250       1      0         0
# 3             70         3         60.0     9550       1      0         0
# 4             60         3         84.0    14260       1      0         0
# ...          ...       ...          ...      ...     ...    ...       ...
# 1454         160         4         21.0     1936       1      0         3
# 1455         160         4         21.0     1894       1      0         3
# 1456          20         3        160.0    20000       1      0         3
# 1457          85         3         62.0    10441       1      0         3
# 1458          60         3         74.0     9627       1      0         3
#
#       LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
train_data['MSSubClass'].unique()
# Out:
# array([ 60,  20,  70,  50, 190,  45,  90, 120,  30,  85,  80, 160,  75,
#        180,  40, 150], dtype=int64)

# %%
train_data.select_dtypes(include=("int64","float64")).isnull().sum().sum()
# Out:
# 2137

# %%
Numeric_columns=train_data.select_dtypes(include=["int64","float64"]).columns
Numeric_columns
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
# for i in Numeric_columns:
#     sns.distplot(train_data[i])
#     plt.show()

# according to distribution graph the data is skewed so we use median

# %%
from sklearn.impute  import SimpleImputer

# %%
si=SimpleImputer(strategy="median")

# %%
# s=si.fit_transform(train_data[['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice']])

# %%
for i in Numeric_columns:
    train_data[[i]]=si.fit_transform(train_data[[i]])

# %%
train_data.select_dtypes(include=("int64","float64")).isnull().sum().sum()
# Out:
# 0

# %%
# for i in train_data.columns:
#     sns.distplot(train_data[i])
#     sns.boxplot(x=i,data=train_data)
#     plt.show()

# %%
for i in train_data.columns:
    q1=train_data[i].quantile(0.25)
    q3=train_data[i].quantile(0.75)
    iqr=q3-q1
    min_range=q1-(1.5*iqr)
    max_range=q3+(1.5*iqr)
    train_data[i]=train_data[i].clip(lower=min_range,upper=max_range)

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
ms=MinMaxScaler()
sd=StandardScaler()

# %%
stdata=train_data

# %%
i
# Out:
# 'SalePrice'

# %%
# for i in train_data:
#     train_data[i]=ms.fit_transform(train_data[[i]])
#     stdata[i]=sd.fit_transform(stdata[[i]])

# %%
train_data.duplicated().sum()
# Out:
# 3

# %%
train_data.drop_duplicates(inplace=True)

# %%
stdata.duplicated().sum()
# Out:
# 0

# %%
stdata.drop_duplicates(inplace=True)

# %%
stdata
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0           60.0         3         65.0   8450.0       1      0         3
# 1           20.0         3         80.0   9600.0       1      0         3
# 2           60.0         3         68.0  11250.0       1      0         0
# 3           70.0         3         60.0   9550.0       1      0         0
# 4           60.0         3         84.0  14260.0       1      0         0
# ...          ...       ...          ...      ...     ...    ...       ...
# 1454       145.0         3         33.0   1936.0       1      0         3
# 1455       145.0         3         33.0   1894.0       1      0         3
# 1456        20.0         3        105.0  17708.0       1      0         3
# 1457        85.0         3         62.0  10441.0       1      0         3
# 1458        60.0         3         74.0   9627.0       1      0         3
#
#       LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
if (stdata['MSZoning'].unique())==stdata['MSZoning'].unique().sum():
    print("hello")
# Out:
# hello

# %%
stdata['MSZoning'].unique().__len__()==1
# Out:
# True

# %%
stdata['LotConfig'].unique().__len__()==1
# Out:
# False

# %%
stdata['LotConfig'].unique().sum()
# Out:
# 10

# %%
stdata.isnull().sum().sum()
# Out:
# 0

# %%
# from sklearn.preprocessing import FunctionTransformer
# ft=FunctionTransformer(func=np.log1p)
# for i in train_data.columns:
#     train_data[i]=ft.fit_transform(train_data[[i]])

# %%
from mlxtend.feature_selection import SequentialFeatureSelector

# %%
x=train_data.iloc[:,:-1]
y=train_data["SalePrice"]

# %%
x.loc[:, 'TotalBath'] = x['FullBath'] + 0.5 * x['HalfBath']
x.drop(columns=['FullBath', 'HalfBath'], inplace=True)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2916 entries, 0 to 1458
# Data columns (total 78 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2916 non-null   float64
#  1   MSZoning       2916 non-null   int32
#  2   LotFrontage    2916 non-null   float64
#  3   LotArea        2916 non-null   float64
#  4   Street         2916 non-null   int32
#  5   Alley          2916 non-null   int32
#  6   LotShape       2916 non-null   int32
#  7   LandContour    2916 non-null   int32
#  8   Utilities      2916 non-null   int32
#  9   LotConfig      2916 non-null   int32
#  10  LandSlope      2916 non-null   int32
#  11  Neighborhood   2916 non-null   int32
#  12  Condition1     2916 non-null   int32
#  13  Condition2     2916 non-null   int32
#  14  BldgType       2916 non-null   int32
#  15  HouseStyle     2916 non-null   int32
#  16  OverallQual    2916 non-null   float64
#  17  OverallCond    2916 non-null   float64
# ...

# %%
x["MSZoning"].unique()
# Out:
# array([3])

# %%
x
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0           60.0         3         65.0   8450.0       1      0         3
# 1           20.0         3         80.0   9600.0       1      0         3
# 2           60.0         3         68.0  11250.0       1      0         0
# 3           70.0         3         60.0   9550.0       1      0         0
# 4           60.0         3         84.0  14260.0       1      0         0
# ...          ...       ...          ...      ...     ...    ...       ...
# 1454       145.0         3         33.0   1936.0       1      0         3
# 1455       145.0         3         33.0   1894.0       1      0         3
# 1456        20.0         3        105.0  17708.0       1      0         3
# 1457        85.0         3         62.0  10441.0       1      0         3
# 1458        60.0         3         74.0   9627.0       1      0         3
#
#       LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
fs=SequentialFeatureSelector(lr,k_features=76,forward=True)
fs.fit(x,y)
# Out:
# SequentialFeatureSelector(estimator=LinearRegression(), k_features=(76, 76),
#                           scoring='r2')

# %%
# fs.feature_names
fs.k_feature_names_
# Out:
# ('MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageCars',
# ...

# %%
s=[]
for i  in fs.k_feature_names_:
    s.append(i)

# %%
xx=x[s]
xx
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0           60.0         3         65.0   8450.0       1      0         3
# 1           20.0         3         80.0   9600.0       1      0         3
# 2           60.0         3         68.0  11250.0       1      0         0
# 3           70.0         3         60.0   9550.0       1      0         0
# 4           60.0         3         84.0  14260.0       1      0         0
# ...          ...       ...          ...      ...     ...    ...       ...
# 1454       145.0         3         33.0   1936.0       1      0         3
# 1455       145.0         3         33.0   1894.0       1      0         3
# 1456        20.0         3        105.0  17708.0       1      0         3
# 1457        85.0         3         62.0  10441.0       1      0         3
# 1458        60.0         3         74.0   9627.0       1      0         3
#
#       LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
(fs.k_score_)*100
# Out:
# 100.0

# %%
X_train = x[s]
y_train = y

# %%
X_train.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0        60.0         3         65.0   8450.0       1      0         3
# 1        20.0         3         80.0   9600.0       1      0         3
# 2        60.0         3         68.0  11250.0       1      0         0
# 3        70.0         3         60.0   9550.0       1      0         0
# 4        60.0         3         84.0  14260.0       1      0         0
#
#    LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# 0            3          0          4  ...       0.0       0      2
# 1            3          0          2  ...       0.0       0      2
# 2            3          0          4  ...       0.0       0      2
# 3            3          0          0  ...       0.0       0      2
# 4            3          0          2  ...       0.0       0      2
#
#    MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  TotalBath
# ...

# %%
# from sklearn.model_selection import train_test_split

# %%
# X_train.loc[:, 'TotalBath'] = X_train['FullBath'] + 0.5 * X_train['HalfBath']
# X_train.drop(columns=['FullBath', 'HalfBath'], inplace=True)

# %%
# X_test = train_data[features].copy()  # Use copy to avoid the SettingWithCopyWarning
# X_test['TotalBath'] = X_test['FullBath'] + 0.5 * X_test['HalfBath']
# X_test.drop(columns=['FullBath', 'HalfBath'], inplace=True)
X_train.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0        60.0         3         65.0   8450.0       1      0         3
# 1        20.0         3         80.0   9600.0       1      0         3
# 2        60.0         3         68.0  11250.0       1      0         0
# 3        70.0         3         60.0   9550.0       1      0         0
# 4        60.0         3         84.0  14260.0       1      0         0
#
#    LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# 0            3          0          4  ...       0.0       0      2
# 1            3          0          2  ...       0.0       0      2
# 2            3          0          4  ...       0.0       0      2
# 3            3          0          0  ...       0.0       0      2
# 4            3          0          2  ...       0.0       0      2
#
#    MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  TotalBath
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)

# %%
X_train,x_test,y_train,y_test=train_test_split(X_train,y_train,test_size=0.2,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 X_train,x_test,y_train,y_test=train_test_split(X_train,y_train,test_size=0.2,random_state=42)
#
# NameError: name 'train_test_split' is not defined

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = model.predict(x_test).reshape(1,-1)

# %%
y_test
# Out:
# 892     0.330709
# 1105    0.668198
# 413     0.233098
# 522     0.341248
# 1036    0.652109
#           ...
# 479     0.164531
# 1361    0.552563
# 802     0.408805
# 651     0.214760
# 722     0.257458
# Name: SalePrice, Length: 292, dtype: float64

# %%
y_train_pred
# Out:
# array([[ 0.30862427,  0.62857056,  0.22909546,  0.38085938,  0.62850952,
#          0.12185669,  0.48126221,  0.28781128,  0.11572266,  0.28979492,
#          0.29275513,  0.23599243,  0.15896606,  0.42599487,  0.40377808,
#          0.28292847,  0.44937134,  0.28509521,  0.20669556,  0.48251343,
#          0.37243652,  0.42965698,  0.40673828,  0.25274658,  0.46035767,
#          0.3555603 ,  0.44171143,  0.20437622,  0.39315796,  0.41540527,
#          0.31036377,  0.53421021,  0.46450806,  0.21047974,  0.52651978,
#          0.32833862,  0.2906189 ,  0.46273804,  0.6244812 ,  0.17532349,
#          0.26730347,  0.51345825,  0.22665405,  0.62384033,  0.25326538,
#          0.27450562,  0.21212769,  0.26055908,  0.71600342,  0.26858521,
#          0.22616577,  0.45492554,  0.24072266,  0.60250854,  0.33407593,
#          0.51638794,  0.47750854,  0.38284302,  0.30535889,  0.19717407,
#          0.06759644,  0.35317993,  0.58398438,  0.53390503,  0.58380127,
# ...

# %%
model.score(x_test,y_test)*100
# Out:
# 89.9242255880025
